# %%
import keras from keras.datasets import mnist
# Out:
#   File "<ipython-input-2-50d001aa274c>", line 1
#     import keras from keras.datasets import mnist
#                     ^
# SyntaxError: invalid syntax

# %%
import keras from keras.datasets import mnist
# Out:
#   File "<ipython-input-3-50d001aa274c>", line 1
#     import keras from keras.datasets import mnist
#                     ^
# SyntaxError: invalid syntax
