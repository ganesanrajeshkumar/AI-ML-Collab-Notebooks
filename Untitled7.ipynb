# %%
import numpy as np

for i in range(10): print(np.exp(-0.0009*i))
# Out:
# 1.0
# 0.9991004048785274
# 0.9982016190284373
# 0.9973036417217132
# 0.9964064722309933
# 0.9955101098295706
# 0.9946145537913912
# 0.9937198033910547
# 0.9928258579038134
# 0.9919327166055711

# %%
requests=np.random.poisson(12)

# %%
m=5

# %%
import random

# %%
requests
# Out:
# 10

# %%
range(1, (m-1)*m +1)
# Out:
# range(1, 21)

# %%
random.sample(range(1, (m-1)*m +1), requests)
# Out:
# [19, 13, 9, 5, 12, 10, 8, 14, 15, 17]

# %%
import nltk

# %%
import re

# %%
print(re.split('\W+',"some of the-words are+combined"))
# Out:
# ['some', 'of', 'the', 'words', 'are', 'combined']
