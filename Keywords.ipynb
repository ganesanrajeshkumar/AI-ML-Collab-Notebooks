# %%
#22/Mar/2021
# Regression:
# --------------
# target variable - target column
# Label - the lables within the target column such as 'Yes' or 'No'. If the target column is numerical, there is only one label
# Regression
# - Single linear regression
# - Multiple linear regression
# Squared Error
# Sum of Squared Errors - SSE
# Mean absolute Error MAE
# Mean Squeared Error
# Root Mean Squared Error
# Residual Plot
# Histograms of Residuals
# R-Squre
# Adjusted R-Square
# Label Encoder
# One-hot-encoder
# ---------------
# Classification :
# ---------------
# Variable :
# - Predictors
# - Covariates
# - Explanatory Variable
# - Independent Variables
# Classification algorithms:
# - Logistic regression ( with L1 or L2 regularization )
# - Decision Trees / Classification Trees / CART / C4.5 / C5.0
# - AdaBoost ( Boosted Decision Trees)
# - Support Vector Machines
# - Random Forests
# - Neural Networks
# Measure classification error
# Overfitting and underfitting
# Statistical Learning Theory
# - Simple Models - underfit
# - Complex Models - Overfit ( training error reduces, test errs increase )
# - Good Models - sweet spot
# Curse of dimensionality
# Regularisation
# Misclassification error 
# F1-score ( value high, model is good )
# Precision
# Recall
# ROC Curve
# Confusion matrix
# bernauli samples
# SVM - Support Vector Machines
# SMOTE - imputation method
