# %%
import numpy as np
import os
import cv2
import function1 as f1
import function2 as f2
import function3 as f3

# %%
#Main call Step 1 of 2 - func1 to func3

#func1_getGreyImg(img)
#func2_faceDetect(img_dir)
#func3_faceRecog(faces,faceid)
#func4_drawRect(test_img,face)
#func5_updLabel(test_img,text,x,y)

#func1 - start
#imgVar = cv2.imread(r"C:\Users\DELL\Documents\PAI-0221A\project\TestImage\Image1.jpg")

#call first function
#facesArr, GreyImg = f1.func1_getGreyImg(imgVar)
#func1 - end
print("***Start executing the scripts***")
faces, faceid = f2.func2_faceDetect(r"C:\Users\DELL\Documents\PAI-0221A\project\images")
facerecognition = f3.func3_faceRecog(faces,faceid)
facerecognition.write(r"C:\Users\DELL\Documents\PAI-0221A\project\face_training.yml")
print("***Finished executing the scripts***")
# Out:
# ***Start executing the scripts***
# ***Finished executing the scripts***
