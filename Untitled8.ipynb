# %%
import requests
api_url = 'http://api.openweathermap.org/data/2.5/weather'
appid = 'b3981278c531bf3ad0f18b71a9b61783'    
r = requests.get(url=api_url, params=dict(q='Anderson', APPID=appid))
r.json()
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 34.5334, 'lon': -82.6499},
#  'dt': 1628216603,
#  'id': 4569313,
#  'main': {'feels_like': 295.92,
#   'humidity': 87,
#   'pressure': 1012,
#   'temp': 295.37,
#   'temp_max': 297.5,
#   'temp_min': 293.01},
#  'name': 'Anderson',
#  'sys': {'country': 'US',
#   'id': 2002953,
#   'sunrise': 1628160247,
#   'sunset': 1628209740,
#   'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#    'icon': '01n',
#    'id': 800,
#    'main': 'Clear'}],
#  'wind': {'deg': 50, 'speed': 2.06}}
