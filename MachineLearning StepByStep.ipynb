# %%
# Steps for Machine learning Models:
# ----------
# Data Preparation
# - histograms
# - Is the data normally distributed?
# - Clean data
# - remove na
# - remove unique values
# ---
# Features extraction
# - Groupby data to see the more effecient data group for prediction
# Model selection
# Evaluate the models
# ----

#STEP 1.Explore and understand the relations of the data
#STEP 2.Tranform the features with mathematical operations
# - Transform with methods such as variance,mean,median, log, exponential,square, square root etc.,
#STEP 3.Visualization results
#STEP 4.Test the ML model
#STEP 5.Repeat manytimes
